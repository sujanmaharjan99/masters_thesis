# %% [markdown]
# <H1>Multivariate prediction of difference in flows</h1>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.express as px
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.discriminant_analysis import StandardScaler
from sklearn.ensemble import GradientBoostingRegressor
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import plotly.graph_objects as go
import os
from plotly.subplots import make_subplots

# %%
directory_list = [
    os.path.join('..', 'Inputs_outputs_excels', 'wsv_rhine_export_with_outliers_balanced.xlsx'),
    os.path.join('..', 'Inputs_outputs_excels', 'wsv_rhine_export - pseudo_huber_29_4_2024.xlsx'),
    os.path.join('..', 'Inputs_outputs_excels', 'wsv_rhine_export_outliers_pseudo_huber.xlsx'),
    os.path.join('..', 'Inputs_outputs_excels', 'rate_of_change_df.xlsx')
]
df = pd.read_excel(directory_list[3])     #This contains the flow.bc (Mass Balance Correction) values

df = df[1:]
df_input = df

df_input_roc= pd.read_excel(directory_list[3])
df_input_roc= df_input_roc[1:-1]

df.index = pd.to_datetime(df['Date'],format='%d.%m.%Y %H:%M:%S')

# %% [markdown]
# <h2>Preprocessing data </h2>

# %% [markdown]
# <h2>Create a new timeseries table with lag</h2>

# %%
lag_input= df[1:]
lag_input=lag_input.rename(columns=lambda col: f"{col}_lag")

# %% [markdown]
# <h3>Input data</h3>

# %%
features_for_input=['ANDER/flow.bc',
                 #'MENDE/flow.bc',
                 #'OPLAD/flow.bc',
                 #'NEUBR/flow.bc',
                 #'RUHRW/flow.bc',
                 #'SCHER/flow.bc',
                 ]
features_for_input_lag=['ANDER/flow.bc_lag',
                 #'MENDE/flow.bc_lag',
                 #'OPLAD/flow.bc_lag',
                 #'NEUBR/flow.bc_lag',
                 #'RUHRW/flow.bc_lag',
                 #'SCHER/flow.bc_lag',
                 ]
features_for_input_roc= ['Rate of change ANDER/flow.bc']

df_input=df_input[features_for_input].reset_index(drop=True)
lag_input=lag_input[features_for_input_lag].reset_index(drop=True)
df_input_roc=df_input_roc[features_for_input_roc].reset_index(drop=True)

df_input
# Out:
#       ANDER/flow.bc
# 0              2120
# 1              2020
# 2              2000
# 3              2090
# 4              2020
# ...             ...
# 3647           1160
# 3648           1110
# 3649           1110
# 3650           1080
# 3651           1070
#
# [3652 rows x 1 columns]

# %%
df_input=pd.concat([df_input,lag_input,df_input_roc],axis=1)

# %% [markdown]
# <h3>Adding periodicity for date</h3>

# %%
time=df['Date']
df_time=pd.DataFrame({'Date': time})
df_time['Seconds']=df_time.index.map(pd.Timestamp.timestamp)

#df_time['Day sin']= np.sin(df_time['Seconds']*(2*np.pi/86400))
#df_time['Day cos']= np.cos(df_time['Seconds']*(2*np.pi/86400))
df_time['Year sin']= np.sin(df_time['Seconds']*(2*np.pi/86400/365.2425))
df_time['Year cos']= np.cos(df_time['Seconds']*(2*np.pi/86400/365.2425))
df_time=df_time.drop('Date',axis=1)
df_time=df_time.drop('Seconds',axis=1)
df_time=df_time.reset_index(drop=True)

# %%
df_input_concatenated=pd.concat([df_time,df_input],axis=1,ignore_index=True)
df_input_concatenated=df_input_concatenated[0:-1]
X_val = df_input_concatenated   #validation dataset

df_input_concatenated
# Out:
#              0         1     2       3      4
# 0    -1.000000  0.000097  2120  2020.0 -120.0
# 1    -0.999850  0.017299  2020  2000.0 -100.0
# 2    -0.999405  0.034495  2000  2090.0  -20.0
# 3    -0.998664  0.051682  2090  2020.0   90.0
# 4    -0.997627  0.068853  2020  1870.0  -70.0
# ...        ...       ...   ...     ...    ...
# 3646 -0.993909 -0.110207  1180  1160.0  -50.0
# 3647 -0.995657 -0.093093  1160  1110.0  -20.0
# 3648 -0.997111 -0.075952  1110  1110.0  -50.0
# 3649 -0.998270 -0.058789  1110  1080.0    0.0
# 3650 -0.999134 -0.041608  1080  1070.0  -30.0
#
# [3651 rows x 5 columns]

# %% [markdown]
# <h3>Creating the label dataframe</h3>

# %%
output_attributes=['BONN/flow.obs',
                   'BONN/flow.bc'
                    #'KOELN/flow.obs',
                    #'DUESS/flow.obs',
                    #'DUISB/flow.obs',
                    #'WESEL/flow.obs',
                    #'REES/flow.obs',
                    #'EMMER/flow.obs'
                    ]
df_output=df[output_attributes]
df_output=df_output[0:-1]
y_val=df_output

# %% [markdown]
# <h2>Splitting data into test, validation and train with window size</h2>

# %%
X_train, X_test, y_train, y_test = train_test_split(df_input_concatenated, df_output, test_size=0.33, random_state=42)

# %%
scaler_x=StandardScaler()
scaler_y=StandardScaler()

X_train_scaled = pd.DataFrame(scaler_x.fit_transform(X_train))
X_test_scaled = pd.DataFrame(scaler_x.transform(X_test))
X_val_scaled = pd.DataFrame(scaler_x.transform(X_val))

y_train_scaled = pd.DataFrame(scaler_y.fit_transform(y_train))
y_test_scaled = pd.DataFrame(scaler_y.transform(y_test))
y_val_scaled= pd.DataFrame(scaler_y.transform(y_val))

# %% [markdown]
# <h1> Feed forward neural network </h1>

# %% [markdown]
# <h2> Define the neural network model</h2>

# %%
model = Sequential([
    Dense(100, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    Dense(100, activation='relu'),
    Dense(y_train_scaled.shape[1])  # Output layer
])
# Out:
# c:\Projects\venv0.7\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# <h2> Compile the model </h2>

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss='mean_squared_error',metrics=['mean_absolute_error'])

# %% [markdown]
# <h2> Model fit </h2>

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history = model.fit(X_train_scaled, y_train_scaled, epochs=200, validation_split=0.3)
# Out:
# Epoch 1/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.0173 - mean_absolute_error: 0.6948 - val_loss: 0.6564 - val_mean_absolute_error: 0.5483
# Epoch 2/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6113 - mean_absolute_error: 0.5410 - val_loss: 0.4281 - val_mean_absolute_error: 0.4305
# Epoch 3/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4334 - mean_absolute_error: 0.4242 - val_loss: 0.2580 - val_mean_absolute_error: 0.3240
# Epoch 4/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2911 - mean_absolute_error: 0.3322 - val_loss: 0.1616 - val_mean_absolute_error: 0.2480
# Epoch 5/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1763 - mean_absolute_error: 0.2520 - val_loss: 0.1125 - val_mean_absolute_error: 0.2037
# Epoch 6/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1172 - mean_absolute_error: 0.2061 - val_loss: 0.0889 - val_mean_absolute_error: 0.1817
# Epoch 7/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1080 - mean_absolute_error: 0.1950 - val_loss: 0.0791 - val_mean_absolute_error: 0.1711
# Epoch 8/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0765 - mean_absolute_error: 0.1694 - val_loss: 0.0753 - val_mean_absolute_error: 0.1665
# Epoch 9/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0759 - mean_absolute_error: 0.1707 - val_loss: 0.0732 - val_mean_absolute_error: 0.1634
# Epoch 10/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0695 - mean_absolute_error: 0.1651 - val_loss: 0.0722 - val_mean_absolute_error: 0.1610
# Epoch 11/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0763 - mean_absolute_error: 0.1681 - val_loss: 0.0716 - val_mean_absolute_error: 0.1600
# Epoch 12/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0744 - mean_absolute_error: 0.1642 - val_loss: 0.0714 - val_mean_absolute_error: 0.1590
# Epoch 13/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0771 - mean_absolute_error: 0.1644 - val_loss: 0.0703 - val_mean_absolute_error: 0.1569
# Epoch 14/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0761 - mean_absolute_error: 0.1673 - val_loss: 0.0697 - val_mean_absolute_error: 0.1559
# Epoch 15/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0653 - mean_absolute_error: 0.1588 - val_loss: 0.0693 - val_mean_absolute_error: 0.1548
# Epoch 16/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0653 - mean_absolute_error: 0.1613 - val_loss: 0.0688 - val_mean_absolute_error: 0.1538
# Epoch 17/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0643 - mean_absolute_error: 0.1550 - val_loss: 0.0692 - val_mean_absolute_error: 0.1535
# Epoch 18/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0662 - mean_absolute_error: 0.1572 - val_loss: 0.0687 - val_mean_absolute_error: 0.1527
# Epoch 19/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0718 - mean_absolute_error: 0.1604 - val_loss: 0.0695 - val_mean_absolute_error: 0.1534
# Epoch 20/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0737 - mean_absolute_error: 0.1613 - val_loss: 0.0694 - val_mean_absolute_error: 0.1530
# Epoch 21/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0700 - mean_absolute_error: 0.1599 - val_loss: 0.0678 - val_mean_absolute_error: 0.1508
# Epoch 22/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0694 - mean_absolute_error: 0.1595 - val_loss: 0.0682 - val_mean_absolute_error: 0.1511
# Epoch 23/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0572 - mean_absolute_error: 0.1485 - val_loss: 0.0678 - val_mean_absolute_error: 0.1500
# Epoch 24/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0610 - mean_absolute_error: 0.1535 - val_loss: 0.0669 - val_mean_absolute_error: 0.1490
# Epoch 25/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0581 - mean_absolute_error: 0.1488 - val_loss: 0.0686 - val_mean_absolute_error: 0.1506
# Epoch 26/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0587 - mean_absolute_error: 0.1501 - val_loss: 0.0674 - val_mean_absolute_error: 0.1492
# Epoch 27/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0626 - mean_absolute_error: 0.1519 - val_loss: 0.0666 - val_mean_absolute_error: 0.1479
# Epoch 28/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0615 - mean_absolute_error: 0.1521 - val_loss: 0.0664 - val_mean_absolute_error: 0.1476
# Epoch 29/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0663 - mean_absolute_error: 0.1536 - val_loss: 0.0671 - val_mean_absolute_error: 0.1478
# Epoch 30/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0660 - mean_absolute_error: 0.1541 - val_loss: 0.0664 - val_mean_absolute_error: 0.1475
# Epoch 31/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0621 - mean_absolute_error: 0.1473 - val_loss: 0.0659 - val_mean_absolute_error: 0.1462
# Epoch 32/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0570 - mean_absolute_error: 0.1461 - val_loss: 0.0653 - val_mean_absolute_error: 0.1458
# Epoch 33/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0621 - mean_absolute_error: 0.1502 - val_loss: 0.0657 - val_mean_absolute_error: 0.1459
# Epoch 34/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0557 - mean_absolute_error: 0.1459 - val_loss: 0.0652 - val_mean_absolute_error: 0.1450
# Epoch 35/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0560 - mean_absolute_error: 0.1439 - val_loss: 0.0658 - val_mean_absolute_error: 0.1453
# Epoch 36/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0571 - mean_absolute_error: 0.1491 - val_loss: 0.0646 - val_mean_absolute_error: 0.1444
# Epoch 37/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0586 - mean_absolute_error: 0.1471 - val_loss: 0.0652 - val_mean_absolute_error: 0.1445
# Epoch 38/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0611 - mean_absolute_error: 0.1464 - val_loss: 0.0664 - val_mean_absolute_error: 0.1454
# Epoch 39/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0562 - mean_absolute_error: 0.1447 - val_loss: 0.0649 - val_mean_absolute_error: 0.1441
# Epoch 40/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0584 - mean_absolute_error: 0.1463 - val_loss: 0.0662 - val_mean_absolute_error: 0.1450
# Epoch 41/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0585 - mean_absolute_error: 0.1472 - val_loss: 0.0644 - val_mean_absolute_error: 0.1430
# Epoch 42/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0609 - mean_absolute_error: 0.1467 - val_loss: 0.0648 - val_mean_absolute_error: 0.1435
# Epoch 43/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0589 - mean_absolute_error: 0.1463 - val_loss: 0.0653 - val_mean_absolute_error: 0.1436
# Epoch 44/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0567 - mean_absolute_error: 0.1449 - val_loss: 0.0637 - val_mean_absolute_error: 0.1422
# Epoch 45/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0532 - mean_absolute_error: 0.1409 - val_loss: 0.0638 - val_mean_absolute_error: 0.1421
# Epoch 46/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0545 - mean_absolute_error: 0.1432 - val_loss: 0.0641 - val_mean_absolute_error: 0.1426
# Epoch 47/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0586 - mean_absolute_error: 0.1455 - val_loss: 0.0646 - val_mean_absolute_error: 0.1425
# Epoch 48/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0610 - mean_absolute_error: 0.1465 - val_loss: 0.0638 - val_mean_absolute_error: 0.1421
# Epoch 49/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0613 - mean_absolute_error: 0.1460 - val_loss: 0.0643 - val_mean_absolute_error: 0.1424
# Epoch 50/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0542 - mean_absolute_error: 0.1408 - val_loss: 0.0637 - val_mean_absolute_error: 0.1413
# Epoch 51/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0581 - mean_absolute_error: 0.1457 - val_loss: 0.0638 - val_mean_absolute_error: 0.1418
# Epoch 52/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0557 - mean_absolute_error: 0.1416 - val_loss: 0.0636 - val_mean_absolute_error: 0.1414
# Epoch 53/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0547 - mean_absolute_error: 0.1432 - val_loss: 0.0633 - val_mean_absolute_error: 0.1407
# Epoch 54/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0609 - mean_absolute_error: 0.1424 - val_loss: 0.0635 - val_mean_absolute_error: 0.1408
# Epoch 55/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0602 - mean_absolute_error: 0.1442 - val_loss: 0.0644 - val_mean_absolute_error: 0.1415
# Epoch 56/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0550 - mean_absolute_error: 0.1418 - val_loss: 0.0626 - val_mean_absolute_error: 0.1401
# Epoch 57/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0575 - mean_absolute_error: 0.1418 - val_loss: 0.0632 - val_mean_absolute_error: 0.1403
# Epoch 58/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0510 - mean_absolute_error: 0.1370 - val_loss: 0.0630 - val_mean_absolute_error: 0.1404
# Epoch 59/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0543 - mean_absolute_error: 0.1403 - val_loss: 0.0623 - val_mean_absolute_error: 0.1395
# Epoch 60/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0525 - mean_absolute_error: 0.1387 - val_loss: 0.0626 - val_mean_absolute_error: 0.1399
# Epoch 61/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0591 - mean_absolute_error: 0.1428 - val_loss: 0.0627 - val_mean_absolute_error: 0.1396
# Epoch 62/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0569 - mean_absolute_error: 0.1446 - val_loss: 0.0618 - val_mean_absolute_error: 0.1390
# Epoch 63/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0573 - mean_absolute_error: 0.1438 - val_loss: 0.0614 - val_mean_absolute_error: 0.1387
# Epoch 64/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0537 - mean_absolute_error: 0.1407 - val_loss: 0.0621 - val_mean_absolute_error: 0.1390
# Epoch 65/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0570 - mean_absolute_error: 0.1440 - val_loss: 0.0625 - val_mean_absolute_error: 0.1394
# Epoch 66/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0501 - mean_absolute_error: 0.1352 - val_loss: 0.0627 - val_mean_absolute_error: 0.1395
# Epoch 67/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0517 - mean_absolute_error: 0.1380 - val_loss: 0.0607 - val_mean_absolute_error: 0.1384
# Epoch 68/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0580 - mean_absolute_error: 0.1419 - val_loss: 0.0617 - val_mean_absolute_error: 0.1385
# Epoch 69/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0566 - mean_absolute_error: 0.1395 - val_loss: 0.0613 - val_mean_absolute_error: 0.1388
# Epoch 70/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0558 - mean_absolute_error: 0.1393 - val_loss: 0.0615 - val_mean_absolute_error: 0.1386
# Epoch 71/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0539 - mean_absolute_error: 0.1409 - val_loss: 0.0625 - val_mean_absolute_error: 0.1389
# Epoch 72/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0566 - mean_absolute_error: 0.1426 - val_loss: 0.0614 - val_mean_absolute_error: 0.1386
# Epoch 73/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0513 - mean_absolute_error: 0.1373 - val_loss: 0.0612 - val_mean_absolute_error: 0.1380
# Epoch 74/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0549 - mean_absolute_error: 0.1411 - val_loss: 0.0612 - val_mean_absolute_error: 0.1379
# Epoch 75/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0566 - mean_absolute_error: 0.1414 - val_loss: 0.0609 - val_mean_absolute_error: 0.1375
# Epoch 76/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0593 - mean_absolute_error: 0.1418 - val_loss: 0.0606 - val_mean_absolute_error: 0.1372
# Epoch 77/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0492 - mean_absolute_error: 0.1344 - val_loss: 0.0604 - val_mean_absolute_error: 0.1372
# Epoch 78/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0542 - mean_absolute_error: 0.1402 - val_loss: 0.0609 - val_mean_absolute_error: 0.1372
# Epoch 79/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0548 - mean_absolute_error: 0.1392 - val_loss: 0.0616 - val_mean_absolute_error: 0.1379
# Epoch 80/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0562 - mean_absolute_error: 0.1407 - val_loss: 0.0608 - val_mean_absolute_error: 0.1371
# Epoch 81/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0510 - mean_absolute_error: 0.1369 - val_loss: 0.0610 - val_mean_absolute_error: 0.1370
# Epoch 82/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0542 - mean_absolute_error: 0.1365 - val_loss: 0.0607 - val_mean_absolute_error: 0.1369
# Epoch 83/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0526 - mean_absolute_error: 0.1359 - val_loss: 0.0604 - val_mean_absolute_error: 0.1372
# Epoch 84/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0537 - mean_absolute_error: 0.1368 - val_loss: 0.0599 - val_mean_absolute_error: 0.1369
# Epoch 85/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0529 - mean_absolute_error: 0.1383 - val_loss: 0.0598 - val_mean_absolute_error: 0.1363
# Epoch 86/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0509 - mean_absolute_error: 0.1360 - val_loss: 0.0615 - val_mean_absolute_error: 0.1381
# Epoch 87/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0551 - mean_absolute_error: 0.1383 - val_loss: 0.0602 - val_mean_absolute_error: 0.1369
# Epoch 88/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0536 - mean_absolute_error: 0.1379 - val_loss: 0.0608 - val_mean_absolute_error: 0.1372
# Epoch 89/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0537 - mean_absolute_error: 0.1360 - val_loss: 0.0606 - val_mean_absolute_error: 0.1368
# Epoch 90/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0535 - mean_absolute_error: 0.1394 - val_loss: 0.0602 - val_mean_absolute_error: 0.1364
# Epoch 91/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0486 - mean_absolute_error: 0.1335 - val_loss: 0.0596 - val_mean_absolute_error: 0.1362
# Epoch 92/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0512 - mean_absolute_error: 0.1361 - val_loss: 0.0595 - val_mean_absolute_error: 0.1359
# Epoch 93/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0543 - mean_absolute_error: 0.1388 - val_loss: 0.0612 - val_mean_absolute_error: 0.1366
# Epoch 94/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0530 - mean_absolute_error: 0.1336 - val_loss: 0.0615 - val_mean_absolute_error: 0.1370
# Epoch 95/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0560 - mean_absolute_error: 0.1394 - val_loss: 0.0598 - val_mean_absolute_error: 0.1359
# Epoch 96/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0550 - mean_absolute_error: 0.1365 - val_loss: 0.0606 - val_mean_absolute_error: 0.1363
# Epoch 97/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0565 - mean_absolute_error: 0.1409 - val_loss: 0.0596 - val_mean_absolute_error: 0.1362
# Epoch 98/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0535 - mean_absolute_error: 0.1372 - val_loss: 0.0610 - val_mean_absolute_error: 0.1364
# Epoch 99/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0546 - mean_absolute_error: 0.1376 - val_loss: 0.0595 - val_mean_absolute_error: 0.1358
# Epoch 100/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0481 - mean_absolute_error: 0.1337 - val_loss: 0.0596 - val_mean_absolute_error: 0.1365
# Epoch 101/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0522 - mean_absolute_error: 0.1366 - val_loss: 0.0591 - val_mean_absolute_error: 0.1356
# Epoch 102/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0484 - mean_absolute_error: 0.1334 - val_loss: 0.0596 - val_mean_absolute_error: 0.1359
# Epoch 103/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0570 - mean_absolute_error: 0.1411 - val_loss: 0.0591 - val_mean_absolute_error: 0.1354
# Epoch 104/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0522 - mean_absolute_error: 0.1347 - val_loss: 0.0604 - val_mean_absolute_error: 0.1360
# Epoch 105/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0559 - mean_absolute_error: 0.1390 - val_loss: 0.0595 - val_mean_absolute_error: 0.1354
# Epoch 106/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0537 - mean_absolute_error: 0.1368 - val_loss: 0.0599 - val_mean_absolute_error: 0.1358
# Epoch 107/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0523 - mean_absolute_error: 0.1365 - val_loss: 0.0607 - val_mean_absolute_error: 0.1363
# Epoch 108/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0560 - mean_absolute_error: 0.1376 - val_loss: 0.0608 - val_mean_absolute_error: 0.1364
# Epoch 109/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0510 - mean_absolute_error: 0.1326 - val_loss: 0.0593 - val_mean_absolute_error: 0.1355
# Epoch 110/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0513 - mean_absolute_error: 0.1326 - val_loss: 0.0599 - val_mean_absolute_error: 0.1356
# Epoch 111/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0543 - mean_absolute_error: 0.1373 - val_loss: 0.0596 - val_mean_absolute_error: 0.1356
# Epoch 112/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0534 - mean_absolute_error: 0.1350 - val_loss: 0.0599 - val_mean_absolute_error: 0.1356
# Epoch 113/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0525 - mean_absolute_error: 0.1341 - val_loss: 0.0589 - val_mean_absolute_error: 0.1349
# Epoch 114/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0504 - mean_absolute_error: 0.1363 - val_loss: 0.0590 - val_mean_absolute_error: 0.1349
# Epoch 115/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0508 - mean_absolute_error: 0.1345 - val_loss: 0.0588 - val_mean_absolute_error: 0.1346
# Epoch 116/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0496 - mean_absolute_error: 0.1344 - val_loss: 0.0596 - val_mean_absolute_error: 0.1358
# Epoch 117/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0521 - mean_absolute_error: 0.1339 - val_loss: 0.0583 - val_mean_absolute_error: 0.1346
# Epoch 118/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0518 - mean_absolute_error: 0.1340 - val_loss: 0.0595 - val_mean_absolute_error: 0.1355
# Epoch 119/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0540 - mean_absolute_error: 0.1362 - val_loss: 0.0589 - val_mean_absolute_error: 0.1348
# Epoch 120/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0493 - mean_absolute_error: 0.1338 - val_loss: 0.0592 - val_mean_absolute_error: 0.1351
# Epoch 121/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0492 - mean_absolute_error: 0.1325 - val_loss: 0.0589 - val_mean_absolute_error: 0.1346
# Epoch 122/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0500 - mean_absolute_error: 0.1335 - val_loss: 0.0585 - val_mean_absolute_error: 0.1345
# Epoch 123/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0500 - mean_absolute_error: 0.1339 - val_loss: 0.0589 - val_mean_absolute_error: 0.1348
# Epoch 124/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0476 - mean_absolute_error: 0.1319 - val_loss: 0.0581 - val_mean_absolute_error: 0.1344
# Epoch 125/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0507 - mean_absolute_error: 0.1330 - val_loss: 0.0584 - val_mean_absolute_error: 0.1343
# Epoch 126/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0529 - mean_absolute_error: 0.1368 - val_loss: 0.0596 - val_mean_absolute_error: 0.1353
# Epoch 127/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0560 - mean_absolute_error: 0.1378 - val_loss: 0.0589 - val_mean_absolute_error: 0.1346
# Epoch 128/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0525 - mean_absolute_error: 0.1336 - val_loss: 0.0595 - val_mean_absolute_error: 0.1355
# Epoch 129/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0473 - mean_absolute_error: 0.1323 - val_loss: 0.0580 - val_mean_absolute_error: 0.1339
# Epoch 130/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0545 - mean_absolute_error: 0.1369 - val_loss: 0.0581 - val_mean_absolute_error: 0.1342
# Epoch 131/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0509 - mean_absolute_error: 0.1357 - val_loss: 0.0595 - val_mean_absolute_error: 0.1349
# Epoch 132/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0515 - mean_absolute_error: 0.1347 - val_loss: 0.0584 - val_mean_absolute_error: 0.1341
# Epoch 133/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0479 - mean_absolute_error: 0.1325 - val_loss: 0.0593 - val_mean_absolute_error: 0.1349
# Epoch 134/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0482 - mean_absolute_error: 0.1313 - val_loss: 0.0574 - val_mean_absolute_error: 0.1333
# Epoch 135/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0511 - mean_absolute_error: 0.1347 - val_loss: 0.0593 - val_mean_absolute_error: 0.1346
# Epoch 136/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0471 - mean_absolute_error: 0.1320 - val_loss: 0.0586 - val_mean_absolute_error: 0.1341
# Epoch 137/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0512 - mean_absolute_error: 0.1348 - val_loss: 0.0577 - val_mean_absolute_error: 0.1338
# Epoch 138/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0492 - mean_absolute_error: 0.1304 - val_loss: 0.0586 - val_mean_absolute_error: 0.1343
# Epoch 139/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0470 - mean_absolute_error: 0.1321 - val_loss: 0.0585 - val_mean_absolute_error: 0.1341
# Epoch 140/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0517 - mean_absolute_error: 0.1351 - val_loss: 0.0597 - val_mean_absolute_error: 0.1351
# Epoch 141/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0502 - mean_absolute_error: 0.1334 - val_loss: 0.0579 - val_mean_absolute_error: 0.1339
# Epoch 142/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0530 - mean_absolute_error: 0.1351 - val_loss: 0.0575 - val_mean_absolute_error: 0.1334
# Epoch 143/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0494 - mean_absolute_error: 0.1331 - val_loss: 0.0577 - val_mean_absolute_error: 0.1335
# Epoch 144/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0507 - mean_absolute_error: 0.1338 - val_loss: 0.0594 - val_mean_absolute_error: 0.1348
# Epoch 145/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0532 - mean_absolute_error: 0.1367 - val_loss: 0.0577 - val_mean_absolute_error: 0.1334
# Epoch 146/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0466 - mean_absolute_error: 0.1314 - val_loss: 0.0581 - val_mean_absolute_error: 0.1336
# Epoch 147/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0443 - mean_absolute_error: 0.1291 - val_loss: 0.0578 - val_mean_absolute_error: 0.1337
# Epoch 148/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0506 - mean_absolute_error: 0.1328 - val_loss: 0.0581 - val_mean_absolute_error: 0.1339
# Epoch 149/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0572 - mean_absolute_error: 0.1353 - val_loss: 0.0588 - val_mean_absolute_error: 0.1342
# Epoch 150/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0468 - mean_absolute_error: 0.1293 - val_loss: 0.0572 - val_mean_absolute_error: 0.1333
# Epoch 151/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0484 - mean_absolute_error: 0.1294 - val_loss: 0.0582 - val_mean_absolute_error: 0.1339
# Epoch 152/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0492 - mean_absolute_error: 0.1331 - val_loss: 0.0572 - val_mean_absolute_error: 0.1327
# Epoch 153/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0488 - mean_absolute_error: 0.1305 - val_loss: 0.0584 - val_mean_absolute_error: 0.1337
# Epoch 154/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0461 - mean_absolute_error: 0.1298 - val_loss: 0.0574 - val_mean_absolute_error: 0.1340
# Epoch 155/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0493 - mean_absolute_error: 0.1323 - val_loss: 0.0581 - val_mean_absolute_error: 0.1332
# Epoch 156/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0489 - mean_absolute_error: 0.1300 - val_loss: 0.0575 - val_mean_absolute_error: 0.1333
# Epoch 157/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0476 - mean_absolute_error: 0.1291 - val_loss: 0.0574 - val_mean_absolute_error: 0.1329
# Epoch 158/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0494 - mean_absolute_error: 0.1298 - val_loss: 0.0578 - val_mean_absolute_error: 0.1335
# Epoch 159/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0568 - mean_absolute_error: 0.1387 - val_loss: 0.0590 - val_mean_absolute_error: 0.1346
# Epoch 160/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0472 - mean_absolute_error: 0.1303 - val_loss: 0.0570 - val_mean_absolute_error: 0.1328
# Epoch 161/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mean_absolute_error: 0.1320 - val_loss: 0.0575 - val_mean_absolute_error: 0.1330
# Epoch 162/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0473 - mean_absolute_error: 0.1284 - val_loss: 0.0575 - val_mean_absolute_error: 0.1331
# Epoch 163/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0478 - mean_absolute_error: 0.1305 - val_loss: 0.0583 - val_mean_absolute_error: 0.1337
# Epoch 164/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0502 - mean_absolute_error: 0.1327 - val_loss: 0.0578 - val_mean_absolute_error: 0.1333
# Epoch 165/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0535 - mean_absolute_error: 0.1346 - val_loss: 0.0584 - val_mean_absolute_error: 0.1336
# Epoch 166/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0500 - mean_absolute_error: 0.1326 - val_loss: 0.0578 - val_mean_absolute_error: 0.1333
# Epoch 167/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0504 - mean_absolute_error: 0.1327 - val_loss: 0.0568 - val_mean_absolute_error: 0.1325
# Epoch 168/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0453 - mean_absolute_error: 0.1286 - val_loss: 0.0567 - val_mean_absolute_error: 0.1324
# Epoch 169/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0483 - mean_absolute_error: 0.1298 - val_loss: 0.0568 - val_mean_absolute_error: 0.1324
# Epoch 170/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0452 - mean_absolute_error: 0.1283 - val_loss: 0.0570 - val_mean_absolute_error: 0.1324
# Epoch 171/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0460 - mean_absolute_error: 0.1274 - val_loss: 0.0575 - val_mean_absolute_error: 0.1327
# Epoch 172/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0466 - mean_absolute_error: 0.1281 - val_loss: 0.0573 - val_mean_absolute_error: 0.1326
# Epoch 173/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0444 - mean_absolute_error: 0.1283 - val_loss: 0.0570 - val_mean_absolute_error: 0.1324
# Epoch 174/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0515 - mean_absolute_error: 0.1332 - val_loss: 0.0574 - val_mean_absolute_error: 0.1333
# Epoch 175/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0479 - mean_absolute_error: 0.1302 - val_loss: 0.0571 - val_mean_absolute_error: 0.1322
# Epoch 176/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0485 - mean_absolute_error: 0.1267 - val_loss: 0.0590 - val_mean_absolute_error: 0.1339
# Epoch 177/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0455 - mean_absolute_error: 0.1260 - val_loss: 0.0563 - val_mean_absolute_error: 0.1322
# Epoch 178/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0503 - mean_absolute_error: 0.1329 - val_loss: 0.0565 - val_mean_absolute_error: 0.1325
# Epoch 179/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mean_absolute_error: 0.1341 - val_loss: 0.0573 - val_mean_absolute_error: 0.1328
# Epoch 180/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0497 - mean_absolute_error: 0.1344 - val_loss: 0.0577 - val_mean_absolute_error: 0.1328
# Epoch 181/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0476 - mean_absolute_error: 0.1304 - val_loss: 0.0579 - val_mean_absolute_error: 0.1331
# Epoch 182/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0449 - mean_absolute_error: 0.1272 - val_loss: 0.0570 - val_mean_absolute_error: 0.1329
# Epoch 183/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0486 - mean_absolute_error: 0.1320 - val_loss: 0.0576 - val_mean_absolute_error: 0.1329
# Epoch 184/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0502 - mean_absolute_error: 0.1325 - val_loss: 0.0568 - val_mean_absolute_error: 0.1322
# Epoch 185/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0485 - mean_absolute_error: 0.1304 - val_loss: 0.0581 - val_mean_absolute_error: 0.1331
# Epoch 186/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0458 - mean_absolute_error: 0.1268 - val_loss: 0.0573 - val_mean_absolute_error: 0.1338
# Epoch 187/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0504 - mean_absolute_error: 0.1316 - val_loss: 0.0559 - val_mean_absolute_error: 0.1317
# Epoch 188/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0441 - mean_absolute_error: 0.1267 - val_loss: 0.0569 - val_mean_absolute_error: 0.1319
# Epoch 189/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0492 - mean_absolute_error: 0.1310 - val_loss: 0.0568 - val_mean_absolute_error: 0.1324
# Epoch 190/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0496 - mean_absolute_error: 0.1300 - val_loss: 0.0562 - val_mean_absolute_error: 0.1317
# Epoch 191/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0465 - mean_absolute_error: 0.1254 - val_loss: 0.0578 - val_mean_absolute_error: 0.1341
# Epoch 192/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mean_absolute_error: 0.1290 - val_loss: 0.0570 - val_mean_absolute_error: 0.1322
# Epoch 193/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0445 - mean_absolute_error: 0.1275 - val_loss: 0.0562 - val_mean_absolute_error: 0.1321
# Epoch 194/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0485 - mean_absolute_error: 0.1293 - val_loss: 0.0563 - val_mean_absolute_error: 0.1325
# Epoch 195/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0443 - mean_absolute_error: 0.1257 - val_loss: 0.0572 - val_mean_absolute_error: 0.1331
# Epoch 196/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0477 - mean_absolute_error: 0.1298 - val_loss: 0.0575 - val_mean_absolute_error: 0.1326
# Epoch 197/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0440 - mean_absolute_error: 0.1253 - val_loss: 0.0562 - val_mean_absolute_error: 0.1321
# Epoch 198/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0503 - mean_absolute_error: 0.1326 - val_loss: 0.0564 - val_mean_absolute_error: 0.1321
# Epoch 199/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0477 - mean_absolute_error: 0.1300 - val_loss: 0.0567 - val_mean_absolute_error: 0.1320
# Epoch 200/200
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0478 - mean_absolute_error: 0.1291 - val_loss: 0.0560 - val_mean_absolute_error: 0.1320

# %% [markdown]
# <h2>Model evaluation </h2>

# %%
predictions = model.predict(X_test_scaled)
predictions_rescaled = scaler_y.inverse_transform(predictions)
mae_FFNN=mean_absolute_error(y_test, predictions_rescaled)
mse_FFNN=mean_squared_error(y_test, predictions_rescaled)

predictions_FFNN_df=pd.DataFrame(predictions_rescaled)
predictions_FFNN_df.columns=y_test.columns

op=pd.DataFrame(predictions_rescaled)
mae_FFNN, mse_FFNN
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# (21.196052874146318, 1041.1621934376406)

# %% [markdown]
# <h2>Plotting the validation loss and training loss</h2>

# %%
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

# %% [markdown]
# <h2>Validation </h2>

# %%
predictions_val = model.predict(X_val_scaled)
predictions_rescaled_val = scaler_y.inverse_transform(predictions_val)

mae_FFNN_val=mean_absolute_error(y_val, predictions_rescaled_val)
mse_FFNN_val=mean_squared_error(y_val, predictions_rescaled_val)

predictions_FFNN_df_val=pd.DataFrame(predictions_rescaled_val)
predictions_FFNN_df_val.columns=y_val.columns
# Out:
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# <h2>Evaluation metrics for each and every label</h2>

# %%
mae_dict_FFNN_val = {}
mse_dict_FFNN_val = {}
for column in predictions_FFNN_df_val.columns:
    mae_val = mean_absolute_error(y_val[column], predictions_FFNN_df_val[column])
    mse_val = mean_squared_error(y_val[column], predictions_FFNN_df_val[column])
    mae_dict_FFNN_val[column] = mae_val
    mse_dict_FFNN_val[column] = mse_val

print("MAE for each column:")
for column, mae_val in mae_dict_FFNN_val.items():
    print(f"{column}: {mae_val}")

print("\nMSE for each column:")
for column, mse_val in mse_dict_FFNN_val.items():
    print(f"{column}: {mse_val}")
# Out:
# MAE for each column:
# BONN/flow.obs: 27.133685849392716
# BONN/flow.bc: 12.469592938969491
#
# MSE for each column:
# BONN/flow.obs: 1451.1179177371735
# BONN/flow.bc: 278.3765302364528

# %% [markdown]
# <h1>Linear Regression</h1>

# %%
regressor= LinearRegression()

model_linear_disch= regressor.fit(X_val,y_val.iloc[:,0])
prediction_linear_disch= regressor.predict(X_val)

mae_val_lin_disch = mean_absolute_error(y_val.iloc[:,0], prediction_linear_disch)
mse_val_lin_disch = mean_squared_error(y_val.iloc[:,0], prediction_linear_disch)

model_linear= regressor.fit(X_val,y_val.iloc[:,1])
prediction_linear= regressor.predict(X_val)

mae_val_lin = mean_absolute_error(y_val.iloc[:,1], prediction_linear)
mse_val_lin = mean_squared_error(y_val.iloc[:,1], prediction_linear)
mae_val_lin_disch,mae_val_lin
# Out:
# (27.082377265543045, 14.679443262952539)

# %% [markdown]
# <h2>Output visualization</h2>

# %%
i = 0
data = {
    'Date': y_val.index,
    'Discharge MIMO FFNN': predictions_rescaled_val[:, i],
    'Flow observed': np.array(y_val)[:, i],
    'MBC MIMO FFNN': predictions_rescaled_val[:, i+1],
    'MBC Lin Reg': prediction_linear,
    'MBC DA': np.array(y_val)[:, i+1],
}

df_plot_val = pd.DataFrame(data)
df_plot_val['Random error FFNN'] = df_plot_val['MBC DA'] - df_plot_val['MBC MIMO FFNN']
df_plot_val['Random error LR'] = df_plot_val['MBC DA'] - df_plot_val['MBC Lin Reg']

# Create subplots
fig = make_subplots(
    rows=3, cols=1,
    shared_xaxes=True,
    subplot_titles=(
        'Discharge prediction using FFNN ' + df_output.columns[i],
        'MBC prediction ' + df_output.columns[i],
        'Random error ' + df_output.columns[i]
    ),
    vertical_spacing=0.05
)

# Add traces for the first subplot
fig.append_trace(
    go.Scatter(x=df_plot_val['Date'], 
               y=df_plot_val['Discharge MIMO FFNN'],
               mode='lines',
               name='Discharge MIMO FFNN',
               legendgroup='1',
               marker={'color': 'red'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df_plot_val['Date'],
               y=df_plot_val['Flow observed'],
               mode='lines',
               name='Flow observed',
               legendgroup='1',
               marker={'color': 'green'}),
    row=1, col=1
)

# Add traces for the second subplot
fig.append_trace(
    go.Scatter(x=df_plot_val['Date'],
               y=df_plot_val['MBC MIMO FFNN'],
               mode='lines',
               name='MBC MIMO FFNN',
               legendgroup='2',
               marker={'color': 'red'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df_plot_val['Date'],
               y=df_plot_val['MBC DA'],
               mode='lines',
               name='MBC DA',
               legendgroup='2',
               marker={'color': 'blue'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df_plot_val['Date'],
               y=df_plot_val['MBC Lin Reg'],
               mode='lines',
               name='MBC Lin Reg',
               legendgroup='2',
               marker={'color': 'goldenrod'}),
    row=2, col=1
)

# Add traces for the third subplot
fig.append_trace(
    go.Scatter(x=df_plot_val['Date'],
               y=df_plot_val['Random error FFNN'],
               mode='lines',
               name='Random error FFNN',
               legendgroup='3',
               marker={'color': 'red'}),
    row=3, col=1
)
fig.append_trace(
    go.Scatter(x=df_plot_val['Date'],
               y=df_plot_val['MBC DA'],
               mode='lines',
               name='MBC DA',
               legendgroup='3',
               marker={'color': 'blue'}),
    row=3, col=1
)
fig.append_trace(
    go.Scatter(x=df_plot_val['Date'],
               y=df_plot_val['Random error LR'],
               mode='lines',
               name='Random error LR',
               legendgroup='3',
               marker={'color': 'goldenrod'}),
    row=3, col=1
)

# Update layout
fig.update_layout(
    height=1100, width=900,
    template='simple_white',
    xaxis=dict(showline=True, linewidth=1, linecolor='black', mirror=True),
    yaxis=dict(showline=True, linewidth=1, linecolor='black', mirror=True),
    xaxis2=dict(showline=True, linewidth=1, linecolor='black', mirror=True),
    yaxis2=dict(showline=True, linewidth=1, linecolor='black', mirror=True),
    xaxis3=dict(showline=True, linewidth=1, linecolor='black', mirror=True),
    yaxis3=dict(showline=True, linewidth=1, linecolor='black', mirror=True),
    legend_tracegroupgap = 270,
    legend={
        'x': 0.75, # x position
        'y': 0.99, # y position
        'bgcolor': 'rgba(0, 0, 0, 0)'
    }
)

fig.update_xaxes(title_text="Date", row=3, col=1)  # Example for updating x-axis label of the third subplot
fig.update_yaxes(title_text="Discharge (m³/s)", row=1, col=1)
fig.update_yaxes(title_text="MBC (m³/s)", row=2, col=1)
fig.update_yaxes(title_text="Discharge (m³/s)", row=3, col=1)

fig.show()
