# %%
import pandas as pd
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
from datetime import datetime
# %matplotlib inline
import pandas as pd
import os

# %%
directory_list = [
    os.path.join('..', 'Inputs_outputs_excels', 'wsv_main_exportt.xlsx')
]

# %%
df=pd.read_excel(directory_list[0])
df.index = pd.to_datetime(df['Date'],format='%d.%m.%Y %H:%M:%S')
df.columns

# %% [markdown]
# <h1>Würzberg UP to Erlabrunn OP</h1>

# %%
fig = make_subplots(
    rows=3, cols=1,
    shared_xaxes=True,
    subplot_titles=(
        'Absolute Water level(m)',
        'Discharge (m³/s)',
        'Mass balance correction '
    ),
    vertical_spacing=0.05
)

# Add traces for the first subplot
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['WUEUP/level'],
               mode='lines',
               name='Würzburg UP - SIM',
               legendgroup='1',
               marker={'color': 'blue'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['WUEUP/level.setpoint'],
               mode='lines',
               name='Würzburg UP - OBS',
               line={'dash': 'dash'},
               legendgroup='1',
               marker={'color': 'blue'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['ERLOP/level'],
               mode='lines',
               name='Erlabrunn OP - SIM',
               legendgroup='1',
               marker={'color': 'green'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['ERLOP/level.setpoint'],
               mode='lines',
               name='Erlabrunn OP - OBS',
               line={'dash': 'dash'},
               legendgroup='1',
               marker={'color': 'green'}),
    row=1, col=1
)


# Add traces for the second subplot
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['WUEKW/flow'],
               mode='lines',
               name='Würzburg KW - SIM',
               legendgroup='2',
               marker={'color': 'blue'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['WUEKW/flow.setpoint'],
               mode='lines',
               name='Würzburg KW - OBS',
               line={'dash': 'dash'},
               legendgroup='2',
               marker={'color': 'blue'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['WUERZ/flow.obs'],
               mode='lines',
               name='Würzburg discharge - OBS',
               line={'dash': 'dash'},
               legendgroup='2',
               marker={'color': 'red'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['ERLKW/flow'],
               mode='lines',
               name='Erlabrunn KW - SIM',
               legendgroup='2',
               marker={'color': 'green'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['ERLKW/flow.setpoint'],
               mode='lines',
               name='Erlabrunn KW - OBS',
               line={'dash': 'dash'},
               legendgroup='2',
               marker={'color': 'green'}),
    row=2, col=1
)

# Add traces for the third subplot

fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['ERLOP/flow.bc'],
               mode='lines',
               name='Mass balance correction',
               legendgroup='3',
               marker={'color': 'green'}),
    row=3, col=1
)

# Update layout
fig.update_layout(
    height=1100, width=900,
    template='simple_white',
    xaxis={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    yaxis={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    xaxis2={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    yaxis2={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    xaxis3={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    yaxis3={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    legend_tracegroupgap = 240,
    legend={
        'x': 0.7, # x position
        'y': 0.99, # y position
        'bgcolor': 'rgba(0, 0, 0, 0)'
    }
)

fig.update_xaxes(title_text="Date", row=3, col=1)  # Example for updating x-axis label of the third subplot
fig.update_yaxes(title_text="Absolute gauge height (m)", row=1, col=1)
fig.update_yaxes(title_text="Discharge (m³/s)", row=2, col=1)
fig.update_yaxes(title_text="MBC (m³/s)", row=3, col=1)

fig.show()

# %%
fig = make_subplots(
    rows=3, cols=1,
    shared_xaxes=True,
    subplot_titles=(
        'Absolute Water level(m)',
        'Discharge (m³/s)',
        'Mass balance correction '
    ),
    vertical_spacing=0.05
)

# Add traces for the first subplot
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['WUEUP/level'],
               mode='lines',
               name='Würzburg UP - SIM',
               legendgroup='1',
               marker={'color': 'blue'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['WUEUP/level.setpoint'],
               mode='lines',
               name='Würzburg UP - OBS',
               line={'dash': 'dash'},
               legendgroup='1',
               marker={'color': 'blue'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['ERLOP/level'],
               mode='lines',
               name='Erlabrunn OP - SIM',
               legendgroup='1',
               marker={'color': 'green'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['ERLOP/level.setpoint'],
               mode='lines',
               name='Erlabrunn OP - OBS',
               line={'dash': 'dash'},
               legendgroup='1',
               marker={'color': 'green'}),
    row=1, col=1
)


# Add traces for the second subplot
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['WUEKW/flow'],
               mode='lines',
               name='Würzburg KW - SIM',
               legendgroup='2',
               marker={'color': 'blue'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['WUEKW/flow.setpoint'],
               mode='lines',
               name='Würzburg KW - OBS',
               line={'dash': 'dash'},
               legendgroup='2',
               marker={'color': 'blue'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['WUERZ/flow.obs'],
               mode='lines',
               name='Würzburg discharge - OBS',
               line={'dash': 'dash'},
               legendgroup='2',
               marker={'color': 'red'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['ERLKW/flow'],
               mode='lines',
               name='Erlabrunn KW - SIM',
               legendgroup='2',
               marker={'color': 'green'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['ERLKW/flow.setpoint'],
               mode='lines',
               name='Erlabrunn KW - OBS',
               line={'dash': 'dash'},
               legendgroup='2',
               marker={'color': 'green'}),
    row=2, col=1
)

# Add traces for the third subplot

fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['ERLOP/flow.bc'],
               mode='lines',
               name='Mass balance correction',
               legendgroup='3',
               marker={'color': 'green'}),
    row=3, col=1
)

# Update layout
fig.update_layout(
    height=1100, width=900,
    template='simple_white',
    xaxis={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    yaxis={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    xaxis2={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    yaxis2={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    xaxis3={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    yaxis3={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    legend_tracegroupgap = 240,
    
)

fig.update_xaxes(title_text="Date", row=3, col=1)  # Example for updating x-axis label of the third subplot
fig.update_yaxes(title_text="Absolute gauge height (m)", row=1, col=1)
fig.update_yaxes(title_text="Discharge (m³/s)", row=2, col=1)
fig.update_yaxes(title_text="MBC (m³/s)", row=3, col=1)

fig.show()

# %% [markdown]
# <h1>Erlabrunn UP to Himmelstadt OP</h1>

# %%
fig = make_subplots(
    rows=3, cols=1,
    shared_xaxes=True,
    subplot_titles=(
        'Absolute Water level(m)',
        'Discharge (m³/s)',
        'Mass balance correction '
    ),
    vertical_spacing=0.05
)

# Add traces for the first subplot
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['ERLUP/level'],
               mode='lines',
               name='Erlabrunn UP - SIM',
               legendgroup='1',
               marker={'color': 'blue'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['ERLUP/level.setpoint'],
               mode='lines',
               name='Erlabrunn UP - OBS',
               line={'dash': 'dash'},
               legendgroup='1',
               marker={'color': 'blue'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HIMOP/level'],
               mode='lines',
               name='Himmelstadt OP - SIM',
               legendgroup='1',
               marker={'color': 'green'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HIMOP/level.setpoint'],
               mode='lines',
               name='Himmelstadt OP - OBS',
               line={'dash': 'dash'},
               legendgroup='1',
               marker={'color': 'green'}),
    row=1, col=1
)

########################################################
# Add traces for the second subplot
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['ERLKW/flow'],
               mode='lines',
               name='Erlabrunn KW - SIM',
               legendgroup='2',
               marker={'color': 'blue'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['ERLKW/flow.setpoint'],
               mode='lines',
               name='Erlabrunn KW - OBS',
               line={'dash': 'dash'},
               legendgroup='2',
               marker={'color': 'blue'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HIMKW/flow'],
               mode='lines',
               name='Himmelstadt KW - SIM',
               legendgroup='2',
               marker={'color': 'green'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HIMKW/flow.setpoint'],
               mode='lines',
               name='Himmelstadt KW - OBS',
               line={'dash': 'dash'},
               legendgroup='2',
               marker={'color': 'green'}),
    row=2, col=1
)

######################################################
# Add traces for the third subplot

fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HIMOP/flow.bc'],
               mode='lines',
               name='Mass balance correction',
               legendgroup='3',
               marker={'color': 'green'}),
    row=3, col=1
)

# Update layout
fig.update_layout(
    height=1100, width=900,
    template='simple_white',
    xaxis={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    yaxis={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    xaxis2={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    yaxis2={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    xaxis3={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    yaxis3={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    legend_tracegroupgap = 240,
    legend={
        'x': 0.7, # x position
        'y': 0.99, # y position
        'bgcolor': 'rgba(0, 0, 0, 0)'
    }
)

fig.update_xaxes(title_text="Date", row=3, col=1)  # Example for updating x-axis label of the third subplot
fig.update_yaxes(title_text="Absolute gauge height (m)", row=1, col=1)
fig.update_yaxes(title_text="Discharge (m³/s)", row=2, col=1)
fig.update_yaxes(title_text="MBC (m³/s)", row=3, col=1)

fig.show()

# %% [markdown]
# <h1>Himmelstadt UP to Harrbach OP</h1>

# %%
fig = make_subplots(
    rows=3, cols=1,
    shared_xaxes=True,
    subplot_titles=(
        'Absolute Water level(m)',
        'Discharge (m³/s)',
        'Mass balance correction '
    ),
    vertical_spacing=0.05
)

# Add traces for the first subplot
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HIMUP/level'],
               mode='lines',
               name='Himmelstadt UP - SIM',
               legendgroup='1',
               marker={'color': 'blue'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HIMUP/level.setpoint'],
               mode='lines',
               name='Himmelstadt UP - OBS',
               line={'dash': 'dash'},
               legendgroup='1',
               marker={'color': 'blue'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HAROP/level'],
               mode='lines',
               name='Harrbach OP - SIM',
               legendgroup='1',
               marker={'color': 'green'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HAROP/level.setpoint'],
               mode='lines',
               name='Harrbach OP - OBS',
               line={'dash': 'dash'},
               legendgroup='1',
               marker={'color': 'green'}),
    row=1, col=1
)

########################################################
# Add traces for the second subplot
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HIMKW/flow'],
               mode='lines',
               name='Himmelstadt KW - SIM',
               legendgroup='2',
               marker={'color': 'blue'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HIMKW/flow.setpoint'],
               mode='lines',
               name='Himmelstadt KW - OBS',
               line={'dash': 'dash'},
               legendgroup='2',
               marker={'color': 'blue'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HARKW/flow'],
               mode='lines',
               name='Harrbach KW - SIM',
               legendgroup='2',
               marker={'color': 'green'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HARKW/flow.setpoint'],
               mode='lines',
               name='Harrbach KW - OBS',
               line={'dash': 'dash'},
               legendgroup='2',
               marker={'color': 'green'}),
    row=2, col=1
)

######################################################
# Add traces for the third subplot

fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HAROP/flow.bc'],
               mode='lines',
               name='Mass balance correction',
               legendgroup='3',
               marker={'color': 'green'}),
    row=3, col=1
)

# Update layout
fig.update_layout(
    height=1100, width=900,
    template='simple_white',
    xaxis={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    yaxis={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    xaxis2={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    yaxis2={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    xaxis3={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    yaxis3={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    legend_tracegroupgap = 240,
    legend={
        'x': 0.7, # x position
        'y': 0.99, # y position
        'bgcolor': 'rgba(0, 0, 0, 0)'
    }
)

fig.update_xaxes(title_text="Date", row=3, col=1)  # Example for updating x-axis label of the third subplot
fig.update_yaxes(title_text="Absolute gauge height (m)", row=1, col=1)
fig.update_yaxes(title_text="Discharge (m³/s)", row=2, col=1)
fig.update_yaxes(title_text="MBC (m³/s)", row=3, col=1)

fig.show()

# %% [markdown]
# <h1>Harrbach UP to Steinbach OP</h1>

# %%
fig = make_subplots(
    rows=3, cols=1,
    shared_xaxes=True,
    subplot_titles=(
        'Absolute Water level(m)',
        'Discharge (m³/s)',
        'Mass balance correction '
    ),
    vertical_spacing=0.05
)

# Add traces for the first subplot
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HARUP/level'],
               mode='lines',
               name='Harrbach UP - SIM',
               legendgroup='1',
               marker={'color': 'blue'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HARUP/level.setpoint'],
               mode='lines',
               name='Harrbach UP - OBS',
               line={'dash': 'dash'},
               legendgroup='1',
               marker={'color': 'blue'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['STEOP/level'],
               mode='lines',
               name='Steinbach OP - SIM',
               legendgroup='1',
               marker={'color': 'green'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['STEOP/level.setpoint'],
               mode='lines',
               name='Steinbach OP - OBS',
               line={'dash': 'dash'},
               legendgroup='1',
               marker={'color': 'green'}),
    row=1, col=1
)

########################################################
# Add traces for the second subplot
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HARKW/flow'],
               mode='lines',
               name='Harrbach KW - SIM',
               legendgroup='2',
               marker={'color': 'blue'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HARKW/flow.setpoint'],
               mode='lines',
               name='Harrbach KW - OBS',
               line={'dash': 'dash'},
               legendgroup='2',
               marker={'color': 'blue'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['MFRAE/flow.bc'],
               mode='lines',
               name='Confluence discharge - SIM',
               legendgroup='2',
               marker={'color': 'green'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['MFRAE/flow.setpoint'],
               mode='lines',
               name='Confluence discharge - OBS',
               line={'dash': 'dash'},
               legendgroup='2',
               marker={'color': 'green'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['STEKW/flow'],
               mode='lines',
               name='Steinbach KW - SIM',
               legendgroup='2',
               marker={'color': 'red'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['STEKW/flow.setpoint'],
               mode='lines',
               name='Steinbach KW - OBS',
               line={'dash': 'dash'},
               legendgroup='2',
               marker={'color': 'red'}),
    row=2, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['STEIN/flow.obs'],
               mode='lines',
               name='Steinbach discharge - OBS',
               line={'dash': 'dash'},
               legendgroup='2',
               marker={'color': 'purple'}),
    row=2, col=1
)

######################################################
# Add traces for the third subplot

fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['STEOP/flow.bc'],
               mode='lines',
               name='Mass balance correction',
               legendgroup='3',
               marker={'color': 'green'}),
    row=3, col=1
)

# Update layout
fig.update_layout(
    height=1100, width=900,
    template='simple_white',
    xaxis={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    yaxis={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    xaxis2={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    yaxis2={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    xaxis3={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    yaxis3={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    legend_tracegroupgap = 240,
    legend={
        'x': 0.7, # x position
        'y': 0.99, # y position
        'bgcolor': 'rgba(0, 0, 0, 0)'
    }
)

fig.update_xaxes(title_text="Date", row=3, col=1)  # Example for updating x-axis label of the third subplot
fig.update_yaxes(title_text="Absolute gauge height (m)", row=1, col=1)
fig.update_yaxes(title_text="Discharge (m³/s)", row=2, col=1)
fig.update_yaxes(title_text="MBC (m³/s)", row=3, col=1)

fig.show()

# %% [markdown]
# <h1>Collectively</h1>

# %%
fig = make_subplots(
    rows=1, cols=1,
    shared_xaxes=True,
    subplot_titles=(
        'Mass balance correction (m³/s)',
    ),
    vertical_spacing=0.05
)

# Add traces for the first subplot
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['ERLOP/flow.bc'],
               mode='lines',
               name='ERlabrunn MBC',
               legendgroup='1',
               marker={'color': 'blue'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HIMOP/flow.bc'],
               mode='lines',
               name='Himmelstadt MBC',
               legendgroup='1',
               marker={'color': 'goldenrod'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['HAROP/flow.bc'],
               mode='lines',
               name='Harrbach MBC',
               legendgroup='1',
               marker={'color': 'red'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['MFRAE/flow.bc']-df["MFRAE/flow.setpoint"],
               mode='lines',
               name='MFRAE Confluence MBC',
               legendgroup='1',
               marker={'color': 'green'}),
    row=1, col=1
)
fig.append_trace(
    go.Scatter(x=df['Date'],
               y=df['STEOP/flow.bc'],
               mode='lines',
               name='Steinbach MBC',
               legendgroup='1',
               marker={'color': 'purple'}),
    row=1, col=1
)


# Update layout
fig.update_layout(
    height=1100, width=900,
    template='simple_white',
    xaxis={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    yaxis={'showline': True, 'linewidth': 1, 'linecolor': 'black', 'mirror': True},
    legend={
        'x': 0.7, # x position
        'y': 0.99, # y position
        'bgcolor': 'rgba(0, 0, 0, 0)'
    }
)

fig.update_xaxes(title_text="Date", row=3, col=1)  # Example for updating x-axis label of the third subplot
fig.update_yaxes(title_text="MBC(m³/s)", row=1, col=1)

fig.show()

# %% [markdown]
# <h1>For whole time period<h1>

# %%
import matplotlib.pyplot as plt
import pandas as pd

start_date='01/01/2022'
end_date='31/12/2023'

start_date_obj = datetime.strptime(start_date, '%d/%m/%Y')
end_date_obj = datetime.strptime(end_date, '%d/%m/%Y')

fontdict = {
    "fontsize": 14,
    "fontweight": "bold",
}

t = df.index.values

fig, axs = plt.subplots(3, 1, figsize=(10, 12))

fig.suptitle('               Data assimilation result for station: Erlabrunn', fontsize=13,  x=0.0, ha='left')

axs[0].plot(t, df["WUEUP/level"], "b", label="Würzburg UP - SIM")
axs[0].plot(t, df["WUEUP/level.setpoint"], "c--", label="Würzburg UP - OBS")
axs[0].plot(t, df["ERLOP/level"], "g", label="Erlabrunn OP - SIM")
axs[0].plot(t, df["ERLOP/level.setpoint"], "y--", label="Erlabrunn OP - OBS")
axs[0].set_title("Absolute Water level", fontdict=fontdict)
axs[0].set_xlim(start_date_obj, end_date_obj)
axs[0].set_ylabel("Water level [masl]")
axs[0].grid(True)
axs[0].legend(loc='upper right')

axs[1].plot(t, df["WUEKW/flow"], "b", label="Würzburg KW - SIM")
axs[1].plot(t, df["WUEKW/flow.setpoint"], "c--", label="Würzburg KW - OBS")
axs[1].plot(t, df["WUERZ/flow.obs"], "r--", label="Würzburg discharge - OBS")
axs[1].plot(t, df["ERLKW/flow"], "g", label="Erlabrunn KW - SIM")
axs[1].plot(t, df["ERLKW/flow.setpoint"], "y--", label="Erlabrunn KW - OBS")
axs[1].set_title("Discharge", fontdict=fontdict)
axs[1].set_xlim(start_date_obj, end_date_obj)
axs[1].set_ylabel("Discharge [m³/s]")
axs[1].grid(True)
axs[1].legend(loc='upper right')

axs[2].plot(t, df["ERLOP/flow.bc"], "g", label=f"MBC DA (MAE:{df['ERLOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs[2].set_title("Mass balance correction", fontdict=fontdict)
axs[2].set_xlim(start_date_obj, end_date_obj)
axs[2].set_ylabel("MBC[m³/s]")
axs[2].grid(True)
axs[2].legend(loc='upper right')

plt.tight_layout(h_pad=2.0)
plt.savefig("main1.png", dpi=300, bbox_inches="tight")
plt.close()


fig, axs = plt.subplots(3, 1, figsize=(10, 12))
fig.suptitle('               Data assimilation result for station: Himmelstadt', fontsize=13,  x=0.0, ha='left')

axs[0].plot(t, df["ERLUP/level"], "b", label="Erlabrunn UP - SIM")
axs[0].plot(t, df["ERLUP/level.setpoint"], "c--", label="Erlabrunn UP - OBS")
axs[0].plot(t, df["HIMOP/level"], "g", label="Himmelstadt OP - SIM")
axs[0].plot(t, df["HIMOP/level.setpoint"], "y--", label="Himmelstadt OP - OBS")
axs[0].set_title("Absolute Water level", fontdict=fontdict)
axs[0].set_xlim(start_date_obj, end_date_obj)
axs[0].set_ylabel("Water level [masl]")
axs[0].grid(True)
axs[0].legend(loc='upper right')

axs[1].plot(t, df["ERLKW/flow"], "b", label="Erlabrunn KW - SIM")
axs[1].plot(t, df["ERLKW/flow.setpoint"], "c--", label="Erlabrunn KW - OBS")
axs[1].plot(t, df["HIMKW/flow"], "g", label="Himmelstadt KW - SIM")
axs[1].plot(t, df["HIMKW/flow.setpoint"], "y--", label="Himmelstadt KW - OBS")
axs[1].set_title("Discharge", fontdict=fontdict)
axs[1].set_xlim(start_date_obj, end_date_obj)
axs[1].set_ylabel("Discharge [m³/s]")
axs[1].grid(True)
axs[1].legend(loc='upper right')

axs[2].plot(t, df["HIMOP/flow.bc"], "g", label=f"MBC DA (MAE:{df['HIMOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs[2].set_title("Mass balance correction", fontdict=fontdict)
axs[2].set_xlim(start_date_obj, end_date_obj)
axs[2].set_ylabel("MBC [m³/s]")
axs[2].grid(True)
axs[2].legend(loc='upper right')

plt.tight_layout(h_pad=2.0)
plt.savefig("main2.png", dpi=300, bbox_inches="tight")
plt.close()


fig, axs = plt.subplots(3, 1, figsize=(10, 12))
fig.suptitle('               Data assimilation result for station: Harrbach', fontsize=13,  x=0.0, ha='left')

axs[0].plot(t, df["HIMUP/level"], "b", label="Himmelstadt UP - SIM")
axs[0].plot(t, df["HIMUP/level.setpoint"], "c--", label="Himmelstadt UP - OBS")
axs[0].plot(t, df["HAROP/level"], "g", label="Harrbach OP - SIM")
axs[0].plot(t, df["HAROP/level.setpoint"], "y--", label="Harrbach OP - OBS")
axs[0].set_title("Absolute Water level", fontdict=fontdict)
axs[0].set_xlim(start_date_obj, end_date_obj)
axs[0].set_ylabel("Water level [masl]")
axs[0].grid(True)
axs[0].legend(loc='upper right')

axs[1].plot(t, df["HIMKW/flow"], "b", label="Himmelstadt KW - SIM")
axs[1].plot(t, df["HIMKW/flow.setpoint"], "c--", label="Himmelstadt KW - OBS")
axs[1].plot(t, df["HARKW/flow"], "g", label="Harrbach KW - SIM")
axs[1].plot(t, df["HARKW/flow.setpoint"], "y--", label="Harrbach KW - OBS")
axs[1].set_title("Discharge", fontdict=fontdict)
axs[1].set_xlim(start_date_obj, end_date_obj)
axs[1].set_ylabel("Discharge [m³/s]")
axs[1].grid(True)
axs[1].legend(loc='upper right')

axs[2].plot(t, df["HAROP/flow.bc"], "g", label=f"MBC DA (MAE:{df['HAROP/flow.bc'].iloc[0]:.2f}m³/s)")
axs[2].set_title("Mass balance correction", fontdict=fontdict)
axs[2].set_xlim(start_date_obj, end_date_obj)
axs[2].set_ylabel("MBC [m³/s]")
axs[2].grid(True)
axs[2].legend(loc='upper right')

plt.tight_layout(h_pad=2.0)
plt.savefig("main3.png", dpi=300, bbox_inches="tight")
plt.close()


fig, axs = plt.subplots(3, 1, figsize=(10, 12))
fig.suptitle('               Data assimilation result for station: Steinbach', fontsize=13,  x=0.0, ha='left')
axs[0].plot(t, df["HARUP/level"], "b", label="Harrbach UP - SIM")
axs[0].plot(t, df["HARUP/level.setpoint"], "c--", label="Harrbach UP - OBS")
axs[0].plot(t, df["STEOP/level"], "g", label="Steinbach OP - SIM")
axs[0].plot(t, df["STEOP/level.setpoint"], "y--", label="Steinbach OP - OBS")
axs[0].set_title("Absolute Water level", fontdict=fontdict)
axs[0].set_xlim(start_date_obj, end_date_obj)
axs[0].set_ylabel("Water level [masl]")
axs[0].grid(True)
axs[0].legend(loc='upper right')

axs[1].plot(t, df["HARKW/flow"], "b", label="Harrbach KW - SIM")
axs[1].plot(t, df["HARKW/flow.setpoint"], "c--", label="Harrbach KW - OBS")
axs[1].plot(t, df["MFRAE/flow.bc"], "r", label="Zuflüsse - SIM")
axs[1].plot(t, df["MFRAE/flow.setpoint"], "r--", label="Zuflüsse - OBS")
axs[1].plot(t, df["STEKW/flow"], "g", label="Steinbach KW - SIM")
axs[1].plot(t, df["STEKW/flow.setpoint"], "y--", label="Steinbach KW - OBS")
axs[1].plot(t, df["STEIN/flow.obs"], "c--", label="Steinbach Pegel - OBS")
axs[1].set_title("Discharge", fontdict=fontdict)
axs[1].set_xlim(start_date_obj, end_date_obj)
axs[1].set_ylabel("Discharge [m³/s]")
axs[1].grid(True)
axs[1].legend(loc='upper right')

axs[2].plot(t, df["STEOP/flow.bc"], "g", label=f"MBC DA (MAE:{df['STEOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs[2].set_title("Mass balance correction", fontdict=fontdict)
axs[2].set_xlim(start_date_obj, end_date_obj)
axs[2].set_ylabel("MBC [m³/s]")
axs[2].grid(True)
axs[2].legend(loc='upper right')

plt.tight_layout(h_pad=2.0)
plt.savefig("main4.png", dpi=300, bbox_inches="tight")
plt.close()


fig, axs = plt.subplots(1, 1, figsize=(10, 6))

axs.plot(t, df["ERLOP/flow.bc"], "b", label=f"MBC Erlabrunn (MAE:{df['ERLOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs.plot(t, df["HIMOP/flow.bc"], "g", label=f"MBC Himmelstadt (MAE:{df['HIMOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs.plot(t, df["HAROP/flow.bc"], "c", label=f"MBC Harrbach (MAE:{df['HAROP/flow.bc'].iloc[0]:.2f}m³/s)")
axs.plot(t, df["MFRAE/flow.bc"] - df["MFRAE/flow.setpoint"],"r",label="MBC Steinbach (Confluence) ")
axs.plot(t, df["STEOP/flow.bc"], "m", label=f"MBC Steinbach (MAE:{df['STEOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs.set_title("Mass balance correction", fontdict=fontdict)
axs.set_xlim(start_date_obj, end_date_obj)
axs.set_ylabel("MBC [m³/s]")
axs.grid(True)
axs.legend()

plt.tight_layout(h_pad=2.0)
plt.savefig("main5.png", dpi=300, bbox_inches="tight")
plt.close()

# %% [markdown]
# <h1>For short time period<h1>

# %%
import matplotlib.pyplot as plt
import pandas as pd

start_date='06/03/2023'
end_date='28/03/2023'

start_date_obj = datetime.strptime(start_date, '%d/%m/%Y')
end_date_obj = datetime.strptime(end_date, '%d/%m/%Y')

fontdict = {
    "fontsize": 14,
    "fontweight": "bold",
}

t = df.index.values

fig, axs = plt.subplots(3, 1, figsize=(10, 12))
fig.suptitle('               Data assimilation result for station: Erlabrunn', fontsize=13,  x=0.0, ha='left')
axs[0].plot(t, df["WUEUP/level"], "b", label="Würzburg UP - SIM")
axs[0].plot(t, df["WUEUP/level.setpoint"], "c--", label="Würzburg UP - OBS")
axs[0].plot(t, df["ERLOP/level"], "g", label="Erlabrunn OP - SIM")
axs[0].plot(t, df["ERLOP/level.setpoint"], "y--", label="Erlabrunn OP - OBS")
axs[0].set_title("Absolute Water level", fontdict=fontdict)
axs[0].set_xlim(start_date_obj, end_date_obj)
axs[0].set_ylabel("Water level [masl]")
axs[0].grid(True)
axs[0].legend()

axs[1].plot(t, df["WUEKW/flow"], "b", label="Würzburg KW - SIM")
axs[1].plot(t, df["WUEKW/flow.setpoint"], "c--", label="Würzburg KW - OBS")
axs[1].plot(t, df["WUERZ/flow.obs"], "r--", label="Würzburg discharge - OBS")
axs[1].plot(t, df["ERLKW/flow"], "g", label="Erlabrunn KW - SIM")
axs[1].plot(t, df["ERLKW/flow.setpoint"], "y--", label="Erlabrunn KW - OBS")
axs[1].set_title("Discharge", fontdict=fontdict)
axs[1].set_xlim(start_date_obj, end_date_obj)
axs[1].set_ylabel("Discharge [m³/s]")
axs[1].grid(True)
axs[1].legend()

axs[2].plot(t, df["ERLOP/flow.bc"], "g", label=f"MBC DA (MAE:{df['ERLOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs[2].set_title("Mass balance correction", fontdict=fontdict)
axs[2].set_xlim(start_date_obj, end_date_obj)
axs[2].set_ylabel("MBC[m³/s]")
axs[2].grid(True)
axs[2].legend()

plt.tight_layout(h_pad=2.0)
plt.savefig("main11.png", dpi=300, bbox_inches="tight")
plt.close()


fig, axs = plt.subplots(3, 1, figsize=(10, 12))
fig.suptitle('               Data assimilation result for station: Himmelstadt', fontsize=13,  x=0.0, ha='left')
axs[0].plot(t, df["ERLUP/level"], "b", label="Erlabrunn UP - SIM")
axs[0].plot(t, df["ERLUP/level.setpoint"], "c--", label="Erlabrunn UP - OBS")
axs[0].plot(t, df["HIMOP/level"], "g", label="Himmelstadt OP - SIM")
axs[0].plot(t, df["HIMOP/level.setpoint"], "y--", label="Himmelstadt OP - OBS")
axs[0].set_title("Absolute Water level", fontdict=fontdict)
axs[0].set_xlim(start_date_obj, end_date_obj)
axs[0].set_ylabel("Water level [masl]")
axs[0].grid(True)
axs[0].legend()

axs[1].plot(t, df["ERLKW/flow"], "b", label="Erlabrunn KW - SIM")
axs[1].plot(t, df["ERLKW/flow.setpoint"], "c--", label="Erlabrunn KW - OBS")
axs[1].plot(t, df["HIMKW/flow"], "g", label="Himmelstadt KW - SIM")
axs[1].plot(t, df["HIMKW/flow.setpoint"], "y--", label="Himmelstadt KW - OBS")
axs[1].set_title("Discharge", fontdict=fontdict)
axs[1].set_xlim(start_date_obj, end_date_obj)
axs[1].set_ylabel("Discharge [m³/s]")
axs[1].grid(True)
axs[1].legend()

axs[2].plot(t, df["HIMOP/flow.bc"], "g", label=f"MBC DA (MAE:{df['HIMOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs[2].set_title("Mass balance correction", fontdict=fontdict)
axs[2].set_xlim(start_date_obj, end_date_obj)
axs[2].set_ylabel("MBC [m³/s]")
axs[2].grid(True)
axs[2].legend()

plt.tight_layout(h_pad=2.0)
plt.savefig("main12.png", dpi=300, bbox_inches="tight")
plt.close()


fig, axs = plt.subplots(3, 1, figsize=(10, 12))
fig.suptitle('               Data assimilation result for station: Harrbach', fontsize=13,  x=0.0, ha='left')
axs[0].plot(t, df["HIMUP/level"], "b", label="Himmelstadt UP - SIM")
axs[0].plot(t, df["HIMUP/level.setpoint"], "c--", label="Himmelstadt UP - OBS")
axs[0].plot(t, df["HAROP/level"], "g", label="Harrbach OP - SIM")
axs[0].plot(t, df["HAROP/level.setpoint"], "y--", label="Harrbach OP - OBS")
axs[0].set_title("Absolute Water level", fontdict=fontdict)
axs[0].set_xlim(start_date_obj, end_date_obj)
axs[0].set_ylabel("Water level [masl]")
axs[0].grid(True)
axs[0].legend()

axs[1].plot(t, df["HIMKW/flow"], "b", label="Himmelstadt KW - SIM")
axs[1].plot(t, df["HIMKW/flow.setpoint"], "c--", label="Himmelstadt KW - OBS")
axs[1].plot(t, df["HARKW/flow"], "g", label="Harrbach KW - SIM")
axs[1].plot(t, df["HARKW/flow.setpoint"], "y--", label="Harrbach KW - OBS")
axs[1].set_title("Discharge", fontdict=fontdict)
axs[1].set_xlim(start_date_obj, end_date_obj)
axs[1].set_ylabel("Discharge [m³/s]")
axs[1].grid(True)
axs[1].legend()

axs[2].plot(t, df["HAROP/flow.bc"], "g", label=f"MBC DA (MAE:{df['HAROP/flow.bc'].iloc[0]:.2f}m³/s)")
axs[2].set_title("Mass balance correction", fontdict=fontdict)
axs[2].set_xlim(start_date_obj, end_date_obj)
axs[2].set_ylabel("MBC [m³/s]")
axs[2].grid(True)
axs[2].legend()

plt.tight_layout(h_pad=2.0)
plt.savefig("main13.png", dpi=300, bbox_inches="tight")
plt.close()


fig, axs = plt.subplots(3, 1, figsize=(10, 12))
fig.suptitle('               Data assimilation result for station: Steinbach', fontsize=13,  x=0.0, ha='left')
axs[0].plot(t, df["HARUP/level"], "b", label="Harrbach UP - SIM")
axs[0].plot(t, df["HARUP/level.setpoint"], "c--", label="Harrbach UP - OBS")
axs[0].plot(t, df["STEOP/level"], "g", label="Steinbach OP - SIM")
axs[0].plot(t, df["STEOP/level.setpoint"], "y--", label="Steinbach OP - OBS")
axs[0].set_title("Absolute Water level", fontdict=fontdict)
axs[0].set_xlim(start_date_obj, end_date_obj)
axs[0].set_ylabel("Water level [masl]")
axs[0].grid(True)
axs[0].legend()

axs[1].plot(t, df["HARKW/flow"], "b", label="Harrbach KW - SIM")
axs[1].plot(t, df["HARKW/flow.setpoint"], "c--", label="Harrbach KW - OBS")
axs[1].plot(t, df["MFRAE/flow.bc"], "r", label="Zuflüsse - SIM")
axs[1].plot(t, df["MFRAE/flow.setpoint"], "r--", label="Zuflüsse - OBS")
axs[1].plot(t, df["STEKW/flow"], "g", label="Steinbach KW - SIM")
axs[1].plot(t, df["STEKW/flow.setpoint"], "y--", label="Steinbach KW - OBS")
axs[1].plot(t, df["STEIN/flow.obs"], "c--", label="Steinbach Pegel - OBS")
axs[1].set_title("Discharge", fontdict=fontdict)
axs[1].set_xlim(start_date_obj, end_date_obj)
axs[1].set_ylabel("Discharge [m³/s]")
axs[1].grid(True)
axs[1].legend()

axs[2].plot(t, df["STEOP/flow.bc"], "g", label=f"MBC DA (MAE:{df['STEOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs[2].set_title("Mass balance correction", fontdict=fontdict)
axs[2].set_xlim(start_date_obj, end_date_obj)
axs[2].set_ylabel("MBC [m³/s]")
axs[2].grid(True)
axs[2].legend()

plt.tight_layout(h_pad=2.0)
plt.savefig("main14.png", dpi=300, bbox_inches="tight")
plt.close()


fig, axs = plt.subplots(1, 1, figsize=(10, 6))

axs.plot(t, df["ERLOP/flow.bc"], "b", label=f"MBC Erlabrunn (MAE:{df['ERLOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs.plot(t, df["HIMOP/flow.bc"], "g", label=f"MBC Himmelstadt (MAE:{df['HIMOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs.plot(t, df["HAROP/flow.bc"], "c", label=f"MBC Harrbach (MAE:{df['HAROP/flow.bc'].iloc[0]:.2f}m³/s)")
axs.plot(t, df["MFRAE/flow.bc"] - df["MFRAE/flow.setpoint"],"r",label="MBC Steinbach (Confluence) ")
axs.plot(t, df["STEOP/flow.bc"], "m", label=f"MBC Steinbach (MAE:{df['STEOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs.set_title("Mass balance correction", fontdict=fontdict)
axs.set_xlim(start_date_obj, end_date_obj)
axs.set_ylabel("MBC [m³/s]")
axs.grid(True)
axs.legend()

plt.tight_layout(h_pad=2.0)
plt.savefig("main15.png", dpi=300, bbox_inches="tight")
plt.close()

# %% [markdown]
# <h1>For shorter time period<h1>

# %%
import matplotlib.pyplot as plt
import pandas as pd

start_date='10/03/2023'
end_date='11/03/2023'

start_date_obj = datetime.strptime(start_date, '%d/%m/%Y')
end_date_obj = datetime.strptime(end_date, '%d/%m/%Y')

fontdict = {
    "fontsize": 14,
    "fontweight": "bold",
}

t = df.index.values

fig, axs = plt.subplots(3, 1, figsize=(10, 12))
fig.suptitle('               Data assimilation result for station: Erlabrunn', fontsize=13,  x=0.0, ha='left')
axs[0].plot(t, df["WUEUP/level"], "b", label="Würzburg UP - SIM")
axs[0].plot(t, df["WUEUP/level.setpoint"], "c--", label="Würzburg UP - OBS")
axs[0].plot(t, df["ERLOP/level"], "g", label="Erlabrunn OP - SIM")
axs[0].plot(t, df["ERLOP/level.setpoint"], "y--", label="Erlabrunn OP - OBS")
axs[0].set_title("Absolute Water level", fontdict=fontdict)
axs[0].set_xlim(start_date_obj, end_date_obj)
axs[0].set_ylabel("Water level [masl]")
axs[0].grid(True)
axs[0].legend()

axs[1].plot(t, df["WUEKW/flow"], "b", label="Würzburg KW - SIM")
axs[1].plot(t, df["WUEKW/flow.setpoint"], "c--", label="Würzburg KW - OBS")
axs[1].plot(t, df["WUERZ/flow.obs"], "r--", label="Würzburg discharge - OBS")
axs[1].plot(t, df["ERLKW/flow"], "g", label="Erlabrunn KW - SIM")
axs[1].plot(t, df["ERLKW/flow.setpoint"], "y--", label="Erlabrunn KW - OBS")
axs[1].set_title("Discharge", fontdict=fontdict)
axs[1].set_xlim(start_date_obj, end_date_obj)
axs[1].set_ylabel("Discharge [m³/s]")
axs[1].grid(True)
axs[1].legend()

axs[2].plot(t, df["ERLOP/flow.bc"], "g", label=f"MBC DA (MAE:{df['ERLOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs[2].set_title("Mass balance correction", fontdict=fontdict)
axs[2].set_xlim(start_date_obj, end_date_obj)
axs[2].set_ylabel("MBC[m³/s]")
axs[2].grid(True)
axs[2].legend()

plt.tight_layout(h_pad=2.0)
plt.savefig("main21.png", dpi=300, bbox_inches="tight")
plt.close()


fig, axs = plt.subplots(3, 1, figsize=(10, 12))
fig.suptitle('               Data assimilation result for station: Himmelstadt', fontsize=13,  x=0.0, ha='left')
axs[0].plot(t, df["ERLUP/level"], "b", label="Erlabrunn UP - SIM")
axs[0].plot(t, df["ERLUP/level.setpoint"], "c--", label="Erlabrunn UP - OBS")
axs[0].plot(t, df["HIMOP/level"], "g", label="Himmelstadt OP - SIM")
axs[0].plot(t, df["HIMOP/level.setpoint"], "y--", label="Himmelstadt OP - OBS")
axs[0].set_title("Absolute Water level", fontdict=fontdict)
axs[0].set_xlim(start_date_obj, end_date_obj)
axs[0].set_ylabel("Water level [masl]")
axs[0].grid(True)
axs[0].legend()

axs[1].plot(t, df["ERLKW/flow"], "b", label="Erlabrunn KW - SIM")
axs[1].plot(t, df["ERLKW/flow.setpoint"], "c--", label="Erlabrunn KW - OBS")
axs[1].plot(t, df["HIMKW/flow"], "g", label="Himmelstadt KW - SIM")
axs[1].plot(t, df["HIMKW/flow.setpoint"], "y--", label="Himmelstadt KW - OBS")
axs[1].set_title("Discharge", fontdict=fontdict)
axs[1].set_xlim(start_date_obj, end_date_obj)
axs[1].set_ylabel("Discharge [m³/s]")
axs[1].grid(True)
axs[1].legend()

axs[2].plot(t, df["HIMOP/flow.bc"], "g", label=f"MBC DA (MAE:{df['HIMOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs[2].set_title("Mass balance correction", fontdict=fontdict)
axs[2].set_xlim(start_date_obj, end_date_obj)
axs[2].set_ylabel("MBC [m³/s]")
axs[2].grid(True)
axs[2].legend()

plt.tight_layout(h_pad=2.0)
plt.savefig("main22.png", dpi=300, bbox_inches="tight")
plt.close()


fig, axs = plt.subplots(3, 1, figsize=(10, 12))
fig.suptitle('               Data assimilation result for station: Harrbach', fontsize=13,  x=0.0, ha='left')
axs[0].plot(t, df["HIMUP/level"], "b", label="Himmelstadt UP - SIM")
axs[0].plot(t, df["HIMUP/level.setpoint"], "c--", label="Himmelstadt UP - OBS")
axs[0].plot(t, df["HAROP/level"], "g", label="Harrbach OP - SIM")
axs[0].plot(t, df["HAROP/level.setpoint"], "y--", label="Harrbach OP - OBS")
axs[0].set_title("Absolute Water level", fontdict=fontdict)
axs[0].set_xlim(start_date_obj, end_date_obj)
axs[0].set_ylabel("Water level [masl]")
axs[0].grid(True)
axs[0].legend()

axs[1].plot(t, df["HIMKW/flow"], "b", label="Himmelstadt KW - SIM")
axs[1].plot(t, df["HIMKW/flow.setpoint"], "c--", label="Himmelstadt KW - OBS")
axs[1].plot(t, df["HARKW/flow"], "g", label="Harrbach KW - SIM")
axs[1].plot(t, df["HARKW/flow.setpoint"], "y--", label="Harrbach KW - OBS")
axs[1].set_title("Discharge", fontdict=fontdict)
axs[1].set_xlim(start_date_obj, end_date_obj)
axs[1].set_ylabel("Discharge [m³/s]")
axs[1].grid(True)
axs[1].legend()

axs[2].plot(t, df["HAROP/flow.bc"], "g", label=f"MBC DA (MAE:{df['HAROP/flow.bc'].iloc[0]:.2f}m³/s)")
axs[2].set_title("Mass balance correction", fontdict=fontdict)
axs[2].set_xlim(start_date_obj, end_date_obj)
axs[2].set_ylabel("MBC [m³/s]")
axs[2].grid(True)
axs[2].legend()

plt.tight_layout(h_pad=2.0)
plt.savefig("main23.png", dpi=300, bbox_inches="tight")
plt.close()


fig, axs = plt.subplots(3, 1, figsize=(10, 12))
fig.suptitle('               Data assimilation result for station: Steinbach', fontsize=13,  x=0.0, ha='left')
axs[0].plot(t, df["HARUP/level"], "b", label="Harrbach UP - SIM")
axs[0].plot(t, df["HARUP/level.setpoint"], "c--", label="Harrbach UP - OBS")
axs[0].plot(t, df["STEOP/level"], "g", label="Steinbach OP - SIM")
axs[0].plot(t, df["STEOP/level.setpoint"], "y--", label="Steinbach OP - OBS")
axs[0].set_title("Absolute Water level", fontdict=fontdict)
axs[0].set_xlim(start_date_obj, end_date_obj)
axs[0].set_ylabel("Water level [masl]")
axs[0].grid(True)
axs[0].legend()

axs[1].plot(t, df["HARKW/flow"], "b", label="Harrbach KW - SIM")
axs[1].plot(t, df["HARKW/flow.setpoint"], "c--", label="Harrbach KW - OBS")
axs[1].plot(t, df["MFRAE/flow.bc"], "r", label="Zuflüsse - SIM")
axs[1].plot(t, df["MFRAE/flow.setpoint"], "r--", label="Zuflüsse - OBS")
axs[1].plot(t, df["STEKW/flow"], "g", label="Steinbach KW - SIM")
axs[1].plot(t, df["STEKW/flow.setpoint"], "y--", label="Steinbach KW - OBS")
axs[1].plot(t, df["STEIN/flow.obs"], "c--", label="Steinbach Pegel - OBS")
axs[1].set_title("Discharge", fontdict=fontdict)
axs[1].set_xlim(start_date_obj, end_date_obj)
axs[1].set_ylabel("Discharge [m³/s]")
axs[1].grid(True)
axs[1].legend()

axs[2].plot(t, df["STEOP/flow.bc"], "g", label=f"MBC DA (MAE:{df['STEOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs[2].set_title("Mass balance correction", fontdict=fontdict)
axs[2].set_xlim(start_date_obj, end_date_obj)
axs[2].set_ylabel("MBC [m³/s]")
axs[2].grid(True)
axs[2].legend()

plt.tight_layout(h_pad=2.0)
plt.savefig("main24.png", dpi=300, bbox_inches="tight")
plt.close()


fig, axs = plt.subplots(1, 1, figsize=(10, 6))

axs.plot(t, df["ERLOP/flow.bc"], "b", label=f"MBC Erlabrunn (MAE:{df['ERLOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs.plot(t, df["HIMOP/flow.bc"], "g", label=f"MBC Himmelstadt (MAE:{df['HIMOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs.plot(t, df["HAROP/flow.bc"], "c", label=f"MBC Harrbach (MAE:{df['HAROP/flow.bc'].iloc[0]:.2f}m³/s)")
axs.plot(t, df["MFRAE/flow.bc"] - df["MFRAE/flow.setpoint"],"r",label="MBC Steinbach (Confluence) ")
axs.plot(t, df["STEOP/flow.bc"], "m", label=f"MBC Steinbach (MAE:{df['STEOP/flow.bc'].iloc[0]:.2f}m³/s)")
axs.set_title("Mass balance correction", fontdict=fontdict)
axs.set_xlim(start_date_obj, end_date_obj)
axs.set_ylabel("MBC [m³/s]")
axs.grid(True)
axs.legend()

plt.tight_layout(h_pad=2.0)
plt.savefig("main25.png", dpi=300, bbox_inches="tight")
plt.close()
